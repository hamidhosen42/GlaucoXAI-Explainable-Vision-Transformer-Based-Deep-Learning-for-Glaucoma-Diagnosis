# %% [markdown]
# ### **1. Import the Required Libraries**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from tensorflow import keras
from tensorflow.keras import layers
import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### **2. Load the Image Training and Validation Datasets**

# %% [markdown]
# #### **i. Get the Image Dataset Paths**

# %%
train_dataset_path = '/kaggle/input/fundus-pytorch/train'
validation_dataset_path = '/kaggle/input/fundus-pytorch/val'

# %% [markdown]
# #### **ii. Load Image Datasets and Apply Augmentations**

# %% [markdown]
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32
image_size = (128,128)

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 8621 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 5747 images belonging to 2 classes.

# %% [markdown]
# #### **iii. Get the Label Mappings**

# %% [markdown]
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
label_mapping = {0: "normal", 1: "glaucoma"}
labels = {label_mapping[value]: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# normal : 0
# glaucoma : 1

# %% [markdown]
# ### **3. Plotting Sample Training Images**

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label_index = np.argmax(train_generator[0][1][idx])
        label = list(labels.keys())[label_index]  # Get the key corresponding to the label index
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ### **4. Training a  VGG16 Model**

# %% [markdown]
# Since the training dataset is ready let's create a simple  VGG16 Model to train on the image datasets

# %% [markdown]
# > #### **i. Create a  VGG16 Build Model**

# %%
base_model = keras.applications.VGG16(include_top=False,input_shape=image_size+(3,))
base_model.trainable = False

model = keras.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(2,activation='sigmoid')
])

model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(),
    metrics=[keras.metrics.BinaryAccuracy()]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 2)                 16386
#
# =================================================================
# Total params: 14,731,074
# Trainable params: 16,386
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, expand_nested=True, show_shapes=True, show_layer_names=False)

# %% [markdown]
# #### **ii. Defining Callbacks**

# %% [markdown]
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)

# %% [markdown]
# #### **a. Reduce Learning Rate on Plateau**
#
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %% [markdown]
# #### **iii. Defining the Optimizer**

# %%
optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# #### **iv. Compile the Model**

# %%
model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# #### **v. Training the Model**

# %%
# training
history = model.fit(train_generator,batch_size=32,epochs=50,
        validation_data=validation_generator,verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 270/270 - 247s - loss: 0.5117 - accuracy: 0.7537 - val_loss: 0.4489 - val_accuracy: 0.7973 - lr: 0.0010 - 247s/epoch - 913ms/step
# Epoch 2/50
# 270/270 - 183s - loss: 0.4661 - accuracy: 0.7829 - val_loss: 0.4286 - val_accuracy: 0.8030 - lr: 0.0010 - 183s/epoch - 676ms/step
# Epoch 3/50
# 270/270 - 182s - loss: 0.4320 - accuracy: 0.8014 - val_loss: 0.4199 - val_accuracy: 0.8215 - lr: 0.0010 - 182s/epoch - 673ms/step
# Epoch 4/50
# 270/270 - 172s - loss: 0.4278 - accuracy: 0.8076 - val_loss: 0.4829 - val_accuracy: 0.7964 - lr: 0.0010 - 172s/epoch - 636ms/step
# Epoch 5/50
# 270/270 - 172s - loss: 0.4336 - accuracy: 0.8035 - val_loss: 0.4324 - val_accuracy: 0.8283 - lr: 0.0010 - 172s/epoch - 639ms/step
# Epoch 6/50
# 270/270 - 173s - loss: 0.4163 - accuracy: 0.8114 - val_loss: 0.5609 - val_accuracy: 0.7795 - lr: 0.0010 - 173s/epoch - 640ms/step
# Epoch 7/50
# 270/270 - 172s - loss: 0.4273 - accuracy: 0.8078 - val_loss: 0.4068 - val_accuracy: 0.8262 - lr: 0.0010 - 172s/epoch - 637ms/step
# Epoch 8/50
# 270/270 - 172s - loss: 0.4031 - accuracy: 0.8192 - val_loss: 0.4360 - val_accuracy: 0.8215 - lr: 0.0010 - 172s/epoch - 637ms/step
# Epoch 9/50
# 270/270 - 172s - loss: 0.3983 - accuracy: 0.8193 - val_loss: 0.4079 - val_accuracy: 0.8396 - lr: 0.0010 - 172s/epoch - 637ms/step
# Epoch 10/50
# 270/270 - 172s - loss: 0.4067 - accuracy: 0.8165 - val_loss: 0.4599 - val_accuracy: 0.8269 - lr: 0.0010 - 172s/epoch - 637ms/step
# Epoch 11/50
# 270/270 - 172s - loss: 0.3824 - accuracy: 0.8315 - val_loss: 0.4700 - val_accuracy: 0.8067 - lr: 0.0010 - 172s/epoch - 639ms/step
# Epoch 12/50
# 270/270 - 173s - loss: 0.3826 - accuracy: 0.8260 - val_loss: 0.4525 - val_accuracy: 0.8230 - lr: 0.0010 - 173s/epoch - 639ms/step
# Epoch 13/50
# 270/270 - 173s - loss: 0.3558 - accuracy: 0.8455 - val_loss: 0.3847 - val_accuracy: 0.8521 - lr: 3.1623e-04 - 173s/epoch - 640ms/step
# Epoch 14/50
# 270/270 - 173s - loss: 0.3610 - accuracy: 0.8397 - val_loss: 0.4039 - val_accuracy: 0.8401 - lr: 3.1623e-04 - 173s/epoch - 642ms/step
# Epoch 15/50
# 270/270 - 172s - loss: 0.3576 - accuracy: 0.8424 - val_loss: 0.3959 - val_accuracy: 0.8512 - lr: 3.1623e-04 - 172s/epoch - 637ms/step
# Epoch 16/50
# 270/270 - 171s - loss: 0.3562 - accuracy: 0.8411 - val_loss: 0.3911 - val_accuracy: 0.8350 - lr: 3.1623e-04 - 171s/epoch - 635ms/step
# Epoch 17/50
# 270/270 - 172s - loss: 0.3467 - accuracy: 0.8491 - val_loss: 0.3753 - val_accuracy: 0.8483 - lr: 3.1623e-04 - 172s/epoch - 638ms/step
# Epoch 18/50
# 270/270 - 172s - loss: 0.3495 - accuracy: 0.8453 - val_loss: 0.4299 - val_accuracy: 0.8293 - lr: 3.1623e-04 - 172s/epoch - 638ms/step
# Epoch 19/50
# 270/270 - 172s - loss: 0.3561 - accuracy: 0.8448 - val_loss: 0.3840 - val_accuracy: 0.8498 - lr: 3.1623e-04 - 172s/epoch - 637ms/step
# Epoch 20/50
# 270/270 - 174s - loss: 0.3504 - accuracy: 0.8428 - val_loss: 0.3980 - val_accuracy: 0.8493 - lr: 3.1623e-04 - 174s/epoch - 643ms/step
# Epoch 21/50
# 270/270 - 177s - loss: 0.3516 - accuracy: 0.8443 - val_loss: 0.4163 - val_accuracy: 0.8389 - lr: 3.1623e-04 - 177s/epoch - 655ms/step
# Epoch 22/50
# 270/270 - 175s - loss: 0.3490 - accuracy: 0.8465 - val_loss: 0.4008 - val_accuracy: 0.8472 - lr: 3.1623e-04 - 175s/epoch - 647ms/step
# Epoch 23/50
# 270/270 - 172s - loss: 0.3399 - accuracy: 0.8494 - val_loss: 0.3979 - val_accuracy: 0.8467 - lr: 1.0000e-04 - 172s/epoch - 638ms/step
# Epoch 24/50
# 270/270 - 172s - loss: 0.3363 - accuracy: 0.8554 - val_loss: 0.3806 - val_accuracy: 0.8469 - lr: 1.0000e-04 - 172s/epoch - 636ms/step
# Epoch 25/50
# 270/270 - 172s - loss: 0.3360 - accuracy: 0.8548 - val_loss: 0.3658 - val_accuracy: 0.8531 - lr: 1.0000e-04 - 172s/epoch - 638ms/step
# Epoch 26/50
# 270/270 - 173s - loss: 0.3361 - accuracy: 0.8537 - val_loss: 0.3866 - val_accuracy: 0.8547 - lr: 1.0000e-04 - 173s/epoch - 639ms/step
# Epoch 27/50
# 270/270 - 173s - loss: 0.3343 - accuracy: 0.8564 - val_loss: 0.3934 - val_accuracy: 0.8495 - lr: 1.0000e-04 - 173s/epoch - 640ms/step
# Epoch 28/50
# 270/270 - 172s - loss: 0.3371 - accuracy: 0.8533 - val_loss: 0.3873 - val_accuracy: 0.8476 - lr: 1.0000e-04 - 172s/epoch - 636ms/step
# Epoch 29/50
# 270/270 - 174s - loss: 0.3347 - accuracy: 0.8566 - val_loss: 0.4139 - val_accuracy: 0.8430 - lr: 1.0000e-04 - 174s/epoch - 643ms/step
# Epoch 30/50
# 270/270 - 173s - loss: 0.3361 - accuracy: 0.8530 - val_loss: 0.3998 - val_accuracy: 0.8361 - lr: 1.0000e-04 - 173s/epoch - 640ms/step
# Epoch 31/50
# 270/270 - 173s - loss: 0.3354 - accuracy: 0.8544 - val_loss: 0.3396 - val_accuracy: 0.8528 - lr: 3.1623e-05 - 173s/epoch - 640ms/step
# Epoch 32/50
# 270/270 - 173s - loss: 0.3332 - accuracy: 0.8574 - val_loss: 0.3986 - val_accuracy: 0.8495 - lr: 3.1623e-05 - 173s/epoch - 642ms/step
# Epoch 33/50
# 270/270 - 174s - loss: 0.3333 - accuracy: 0.8536 - val_loss: 0.3991 - val_accuracy: 0.8464 - lr: 3.1623e-05 - 174s/epoch - 643ms/step
# Epoch 34/50
# 270/270 - 173s - loss: 0.3338 - accuracy: 0.8550 - val_loss: 0.3850 - val_accuracy: 0.8486 - lr: 3.1623e-05 - 173s/epoch - 642ms/step
# Epoch 35/50
# 270/270 - 175s - loss: 0.3332 - accuracy: 0.8542 - val_loss: 0.4194 - val_accuracy: 0.8502 - lr: 3.1623e-05 - 175s/epoch - 647ms/step
# Epoch 36/50
# 270/270 - 173s - loss: 0.3333 - accuracy: 0.8547 - val_loss: 0.3735 - val_accuracy: 0.8472 - lr: 3.1623e-05 - 173s/epoch - 640ms/step
# Epoch 37/50
# 270/270 - 175s - loss: 0.3309 - accuracy: 0.8519 - val_loss: 0.3739 - val_accuracy: 0.8502 - lr: 1.0000e-05 - 175s/epoch - 648ms/step
# Epoch 38/50
# 270/270 - 173s - loss: 0.3325 - accuracy: 0.8548 - val_loss: 0.3722 - val_accuracy: 0.8481 - lr: 1.0000e-05 - 173s/epoch - 642ms/step
# Epoch 39/50
# 270/270 - 173s - loss: 0.3331 - accuracy: 0.8580 - val_loss: 0.3921 - val_accuracy: 0.8491 - lr: 1.0000e-05 - 173s/epoch - 640ms/step
# Epoch 40/50
# 270/270 - 173s - loss: 0.3329 - accuracy: 0.8570 - val_loss: 0.4011 - val_accuracy: 0.8467 - lr: 1.0000e-05 - 173s/epoch - 640ms/step
# Epoch 41/50
# 270/270 - 172s - loss: 0.3280 - accuracy: 0.8576 - val_loss: 0.3503 - val_accuracy: 0.8472 - lr: 1.0000e-05 - 172s/epoch - 638ms/step
# Epoch 42/50
# 270/270 - 172s - loss: 0.3308 - accuracy: 0.8596 - val_loss: 0.3723 - val_accuracy: 0.8472 - lr: 3.1623e-06 - 172s/epoch - 637ms/step
# Epoch 43/50
# 270/270 - 172s - loss: 0.3326 - accuracy: 0.8551 - val_loss: 0.4024 - val_accuracy: 0.8483 - lr: 3.1623e-06 - 172s/epoch - 638ms/step
# Epoch 44/50
# 270/270 - 173s - loss: 0.3309 - accuracy: 0.8579 - val_loss: 0.3783 - val_accuracy: 0.8509 - lr: 3.1623e-06 - 173s/epoch - 642ms/step
# Epoch 45/50
# 270/270 - 172s - loss: 0.3342 - accuracy: 0.8534 - val_loss: 0.3960 - val_accuracy: 0.8474 - lr: 3.1623e-06 - 172s/epoch - 639ms/step
# Epoch 46/50
# 270/270 - 174s - loss: 0.3312 - accuracy: 0.8534 - val_loss: 0.4130 - val_accuracy: 0.8467 - lr: 3.1623e-06 - 174s/epoch - 644ms/step
# Epoch 47/50
# 270/270 - 180s - loss: 0.3287 - accuracy: 0.8558 - val_loss: 0.3776 - val_accuracy: 0.8486 - lr: 1.0000e-06 - 180s/epoch - 668ms/step
# Epoch 48/50
# 270/270 - 173s - loss: 0.3339 - accuracy: 0.8554 - val_loss: 0.3551 - val_accuracy: 0.8493 - lr: 1.0000e-06 - 173s/epoch - 640ms/step
# Epoch 49/50
# 270/270 - 171s - loss: 0.3324 - accuracy: 0.8549 - val_loss: 0.3826 - val_accuracy: 0.8484 - lr: 1.0000e-06 - 171s/epoch - 635ms/step
# Epoch 50/50
# 270/270 - 171s - loss: 0.3320 - accuracy: 0.8586 - val_loss: 0.3898 - val_accuracy: 0.8497 - lr: 1.0000e-06 - 171s/epoch - 635ms/step

# %% [markdown]
# ### **5. Plotting the Model Metrics**

# %% [markdown]
# #### **i. Plotting training and validation accuracy, loss and learning rate**

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **6. Testing the Model on Test Set**

# %% [markdown]
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/kaggle/input/fundus-pytorch/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 2874 images belonging to 2 classes.

# %% [markdown]
# ### **7. Model Prediction on the Test Dataset**

# %%
predictions = model.predict(test_generator)
# Out:
# 90/90 [==============================] - 27s 303ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = np.argmax(predictions[idx])
        label = list(labels.keys())[predicted_label]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1


plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        # Extract the predicted label index from the predictions
        predicted_label_index = np.argmax(predictions[idx])
        
        # Get the corresponding label from the dictionary of labels
        predicted_label = list(labels.keys())[predicted_label_index]
        
        # Get the actual label from the generator
        actual_label_index = np.argmax(test_generator[0][1][idx])
        actual_label = list(labels.keys())[actual_label_index]
        
        # Display the actual and predicted labels
        ax[i, j].set_title(f"Actual: {actual_label}\nPredicted: {predicted_label}")
        
        # Display the image
        ax[i, j].imshow(test_generator[0][0][idx])
        
        # Turn off axis
        ax[i, j].axis("off")
        
        # Move to the next image index
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 90/90 [==============================] - 27s 302ms/step - loss: 0.3412 - accuracy: 0.8518

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.3411828279495239
# Test Accuracy: 0.8517745137214661

# %% [markdown]
# The test loss and test accuracy is the same as validation loss and validation accuracy at the last step since the testing and validation datasets are same.

# %% [markdown]
# ### **8. Plotting the Classification Metrics**

# %% [markdown]
# ### **i. Confusion Matrix**

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      1754
#            1       0.91      0.69      0.78      1120
#
#     accuracy                           0.85      2874
#    macro avg       0.87      0.82      0.84      2874
# weighted avg       0.86      0.85      0.85      2874

# %% [markdown]
# ### **9. Wrong Predictions**
#
# Let's see where the model has given wrong predictions and what were the actual predictions on those images.

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = true_index
        label_1 = list(labels.keys())[true_label]
        predicted_index = y_pred_errors[idx]
        predicted_label = list(labels.keys())[predicted_index]
        ax[i, j].set_title(f"True Label: {label_1} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
